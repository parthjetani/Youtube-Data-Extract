# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/My Drive/YouTube')

# %%
pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.6/dist-packages (1.7.12)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.24.0)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (4.7)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (53.0.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (4.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client) (0.4.8)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
youTubeApiKey = "AIzaSyBgkApTimjXdfp7ToYbPrSgCYgAjTtkZjs"
youtube = build('youtube', 'v3', developerKey=youTubeApiKey)

# %%
snippets = youtube.search().list(part="snippet", type="channel", q="nptelhrd").execute()

# %%
snippets
# Out:
# {'etag': 'TXfrzvN2B3rV9ERU0qEKB_HrdQA',
#  'items': [{'etag': 'VQLHwXzRJXL3tKY69MHcb1FHuwU',
#    'id': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#     'channelTitle': 'nptelhrd',
#     'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...',
#     'liveBroadcastContent': 'upcoming',
#     'publishTime': '2007-11-28T04:54:13Z',
#     'publishedAt': '2007-11-28T04:54:13Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngC939TGoPUx9Dm6KljOkaij4gP2eJc5-7Ppb8z9g=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngC939TGoPUx9Dm6KljOkaij4gP2eJc5-7Ppb8z9g=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngC939TGoPUx9Dm6KljOkaij4gP2eJc5-7Ppb8z9g=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'nptelhrd'}},
#   {'etag': 'giGU1cBIJYPPDXeN0hoTJGnk5j0',
#    'id': {'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg',
#     'channelTitle': 'Civil Engineering',
#     'description': 'This channel contains technical lectures on "Civil Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore.',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:21:42Z',
#     'publishedAt': '2013-11-27T11:21:42Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhcUVUl_Rnq8rYPVlY2xr3tVSQBplukTUD6fqht=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhcUVUl_Rnq8rYPVlY2xr3tVSQBplukTUD6fqht=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhcUVUl_Rnq8rYPVlY2xr3tVSQBplukTUD6fqht=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Civil Engineering'}},
#   {'etag': 'gN5HMUx83EDstpBPltYvIPuWuYM',
#    'id': {'channelId': 'UCTJn6buigC961hns17ELXAQ', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCTJn6buigC961hns17ELXAQ',
#     'channelTitle': 'Electrical Engineering',
#     'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:22:52Z',
#     'publishedAt': '2013-11-27T11:22:52Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngXlvdEMM47kTnC4zPt7m5-afOKFt27LyR_iPE=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngXlvdEMM47kTnC4zPt7m5-afOKFt27LyR_iPE=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngXlvdEMM47kTnC4zPt7m5-afOKFt27LyR_iPE=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Electrical Engineering'}},
#   {'etag': 'eB8Vwfm8cJhp__muoFDNDYtV0oA',
#    'id': {'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ',
#     'channelTitle': 'Humanities and Social Sciences',
#     'description': 'This channel contains technical lectures on "Humanities and Social Science" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:27:07Z',
#     'publishedAt': '2013-11-27T11:27:07Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwninIwBnG1QALz2-QF42La6sdOfYEa9PABCLBZEw=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwninIwBnG1QALz2-QF42La6sdOfYEa9PABCLBZEw=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwninIwBnG1QALz2-QF42La6sdOfYEa9PABCLBZEw=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Humanities and Social Sciences'}},
#   {'etag': 'qJEVxYSJDRwnHmxK9QIj7LBpclM',
#    'id': {'channelId': 'UCxJp9aEteKmOeobEsHXwxAw', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCxJp9aEteKmOeobEsHXwxAw',
#     'channelTitle': 'Computer Science and Engineering',
#     'description': 'This channel contains technical lectures on "Computer Science & Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:22:15Z',
#     'publishedAt': '2013-11-27T11:22:15Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhY2EOkcoWiTOVYY13APuoEyTKlFny92lcnPyi1=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhY2EOkcoWiTOVYY13APuoEyTKlFny92lcnPyi1=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhY2EOkcoWiTOVYY13APuoEyTKlFny92lcnPyi1=s240-c-k-c0xffffffff-no-rj-mo'}},
#     'title': 'Computer Science and Engineering'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAUQAA',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 34},
#  'regionCode': 'US'}

# %%
for i in snippets['items']:
    print(i)
# Out:
# {'kind': 'youtube#searchResult', 'etag': 'VQLHwXzRJXL3tKY69MHcb1FHuwU', 'id': {'kind': 'youtube#channel', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA'}, 'snippet': {'publishedAt': '2007-11-28T04:54:13Z', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'title': 'nptelhrd', 'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngC939TGoPUx9Dm6KljOkaij4gP2eJc5-7Ppb8z9g=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngC939TGoPUx9Dm6KljOkaij4gP2eJc5-7Ppb8z9g=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngC939TGoPUx9Dm6KljOkaij4gP2eJc5-7Ppb8z9g=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'nptelhrd', 'liveBroadcastContent': 'upcoming', 'publishTime': '2007-11-28T04:54:13Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'giGU1cBIJYPPDXeN0hoTJGnk5j0', 'id': {'kind': 'youtube#channel', 'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg'}, 'snippet': {'publishedAt': '2013-11-27T11:21:42Z', 'channelId': 'UCAVi5Zg6zSoyZUyKBtCJfmg', 'title': 'Civil Engineering', 'description': 'This channel contains technical lectures on "Civil Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore.', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhcUVUl_Rnq8rYPVlY2xr3tVSQBplukTUD6fqht=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhcUVUl_Rnq8rYPVlY2xr3tVSQBplukTUD6fqht=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhcUVUl_Rnq8rYPVlY2xr3tVSQBplukTUD6fqht=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Civil Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:21:42Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'gN5HMUx83EDstpBPltYvIPuWuYM', 'id': {'kind': 'youtube#channel', 'channelId': 'UCTJn6buigC961hns17ELXAQ'}, 'snippet': {'publishedAt': '2013-11-27T11:22:52Z', 'channelId': 'UCTJn6buigC961hns17ELXAQ', 'title': 'Electrical Engineering', 'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngXlvdEMM47kTnC4zPt7m5-afOKFt27LyR_iPE=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngXlvdEMM47kTnC4zPt7m5-afOKFt27LyR_iPE=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngXlvdEMM47kTnC4zPt7m5-afOKFt27LyR_iPE=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Electrical Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:22:52Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'eB8Vwfm8cJhp__muoFDNDYtV0oA', 'id': {'kind': 'youtube#channel', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ'}, 'snippet': {'publishedAt': '2013-11-27T11:27:07Z', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ', 'title': 'Humanities and Social Sciences', 'description': 'This channel contains technical lectures on "Humanities and Social Science" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwninIwBnG1QALz2-QF42La6sdOfYEa9PABCLBZEw=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwninIwBnG1QALz2-QF42La6sdOfYEa9PABCLBZEw=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwninIwBnG1QALz2-QF42La6sdOfYEa9PABCLBZEw=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Humanities and Social Sciences', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:27:07Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'qJEVxYSJDRwnHmxK9QIj7LBpclM', 'id': {'kind': 'youtube#channel', 'channelId': 'UCxJp9aEteKmOeobEsHXwxAw'}, 'snippet': {'publishedAt': '2013-11-27T11:22:15Z', 'channelId': 'UCxJp9aEteKmOeobEsHXwxAw', 'title': 'Computer Science and Engineering', 'description': 'This channel contains technical lectures on "Computer Science & Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhY2EOkcoWiTOVYY13APuoEyTKlFny92lcnPyi1=s88-c-k-c0xffffffff-no-rj-mo'}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhY2EOkcoWiTOVYY13APuoEyTKlFny92lcnPyi1=s240-c-k-c0xffffffff-no-rj-mo'}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnhY2EOkcoWiTOVYY13APuoEyTKlFny92lcnPyi1=s800-c-k-c0xffffffff-no-rj-mo'}}, 'channelTitle': 'Computer Science and Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:22:15Z'}}

# %%
channelID = snippets['items'][0]['snippet']['channelId']
print("Channel ID of the first channel is " + channelID)
# Out:
# Channel ID of the first channel is UC640y4UvDAlya_WOj5U4pfA

# %%
stats = youtube.channels().list(part="statistics", id = channelID).execute()

# %%
stats['items']
# Out:
# [{'etag': 'i_q4skz_k_XSHYOrI3GBzfxl4J0',
#   'id': 'UC640y4UvDAlya_WOj5U4pfA',
#   'kind': 'youtube#channel',
#   'statistics': {'hiddenSubscriberCount': False,
#    'subscriberCount': '1810000',
#    'videoCount': '20341',
#    'viewCount': '389264788'}}]

# %%
stats
# Out:
# {'etag': 'uwpX_81jXell3zrRnkVZMwPUdGU',
#  'items': [{'etag': 'i_q4skz_k_XSHYOrI3GBzfxl4J0',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA',
#    'kind': 'youtube#channel',
#    'statistics': {'hiddenSubscriberCount': False,
#     'subscriberCount': '1810000',
#     'videoCount': '20341',
#     'viewCount': '389264788'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
content = youtube.channels().list(id = channelID, part = 'contentDetails').execute()
print(content)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': '187NF-Kai-JjwxzeasMVewCsI_8', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'wJNFgVsFjcPi5W07m70UMpvvN1w', 'id': 'UC640y4UvDAlya_WOj5U4pfA', 'contentDetails': {'relatedPlaylists': {'likes': '', 'favorites': '', 'uploads': 'UU640y4UvDAlya_WOj5U4pfA'}}}]}

# %%
content['items']
# Out:
# [{'contentDetails': {'relatedPlaylists': {'favorites': '',
#     'likes': '',
#     'uploads': 'UU640y4UvDAlya_WOj5U4pfA'}},
#   'etag': 'wJNFgVsFjcPi5W07m70UMpvvN1w',
#   'id': 'UC640y4UvDAlya_WOj5U4pfA',
#   'kind': 'youtube#channel'}]

# %%
uploadId = content['items'][0]['contentDetails']['relatedPlaylists']['uploads']
print(uploadId)
# Out:
# UU640y4UvDAlya_WOj5U4pfA

# %%
allVideos = []

# %%
nextPage_token = None

# %%
res  = youtube.playlistItems().list(playlistId = uploadId, maxResults = 50, part = 'snippet', pageToken = nextPage_token).execute()

# %%
while 1:
    res  = youtube.playlistItems().list(playlistId = uploadId, maxResults = 50, part = 'snippet', pageToken = nextPage_token).execute()

    allVideos += res['items']

    nextPage_token = res.get('nextPageToken')

    if nextPage_token is None:
        break
    
    print(allVideos)

# %%
print(len(allVideos))
# Out:
# 20000

# %%
allVideos[0]['snippet']
# Out:
# {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#  'channelTitle': 'nptelhrd',
#  'description': '',
#  'playlistId': 'UU640y4UvDAlya_WOj5U4pfA',
#  'position': 0,
#  'publishedAt': '2021-02-03T10:50:40Z',
#  'resourceId': {'kind': 'youtube#video', 'videoId': '4Z1FjYXdazk'},
#  'thumbnails': {'default': {'height': 90,
#    'url': 'https://i.ytimg.com/vi/4Z1FjYXdazk/default.jpg',
#    'width': 120},
#   'high': {'height': 360,
#    'url': 'https://i.ytimg.com/vi/4Z1FjYXdazk/hqdefault.jpg',
#    'width': 480},
#   'maxres': {'height': 720,
#    'url': 'https://i.ytimg.com/vi/4Z1FjYXdazk/maxresdefault.jpg',
#    'width': 1280},
#   'medium': {'height': 180,
#    'url': 'https://i.ytimg.com/vi/4Z1FjYXdazk/mqdefault.jpg',
#    'width': 320},
#   'standard': {'height': 480,
#    'url': 'https://i.ytimg.com/vi/4Z1FjYXdazk/sddefault.jpg',
#    'width': 640}},
#  'title': 'Awareness Workshop on Credit Transfer and Domain Certification'}

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], allVideos))
print(len(video_ids))
# Out:
# 20000

# %%
stats = []
for i in range(0, len(video_ids), 40):
    res = (youtube).videos().list(id = ',' .join(video_ids[i:i+40]), part='statistics').execute()
    stats += res['items']

print(stats)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
title = []
liked = []
disliked = []
views = []
url = []
comment = []
videoid = []
publishedDate = []
video_description = []

# %%
for i in range(0, 19000):
    i += 1
    title.append((allVideos[i])['snippet']['title'])
    publishedDate.append((allVideos[i])['snippet']['publishedAt'])
    video_description.append((allVideos[i])['snippet']['description'])
    liked.append(int((stats[i])['statistics']['likeCount']))
    disliked.append(int((stats[i])['statistics']['dislikeCount']))
    views.append(int((stats[i])['statistics']['viewCount']))
    #comment.append(int((stats[i])['statistics']['commentCount']))
    videoid.append(allVideos[i]['snippet']['resourceId']['videoId'])

# %%
import pandas as pd
data = {'title':title, 'videoIDS':videoid, 'video_description':video_description, 'publishedDate':publishedDate, 'likes':liked, 'dislikes':disliked, 'views':views}
df = pd.DataFrame.from_dict(data, orient='index')
df = df.transpose()
df.head()
# Out:
#                                            title     videoIDS  ... dislikes views
# 0  Hydro Turbomachines - Francis turbine-Part-02  MtueN0ByKIs  ...        1  1066
# 1                  Thermal Turbomachines-Part-02  vfSm89HwMoc  ...        1   315
# 2                  Thermal Turbomachines-Part-01  tBOvmL04LGw  ...        0   323
# 3         Thermal Turbomachines - Steam Turbines  I6ali5qxu6I  ...        0   336
# 4           Thermal Turbomachines - Gas turbines  VvCvrOQ9NsM  ...        0   310
#
# [5 rows x 7 columns]

# %%
df.to_csv('ExtractedData.csv', index = False)

# %%
data = pd.read_csv('ExtractedData.csv')
data.head()
# Out:
#                                            title     videoIDS  ... dislikes views
# 0  Hydro Turbomachines - Francis turbine-Part-02  MtueN0ByKIs  ...        1  1066
# 1                  Thermal Turbomachines-Part-02  vfSm89HwMoc  ...        1   315
# 2                  Thermal Turbomachines-Part-01  tBOvmL04LGw  ...        0   323
# 3         Thermal Turbomachines - Steam Turbines  I6ali5qxu6I  ...        0   336
# 4           Thermal Turbomachines - Gas turbines  VvCvrOQ9NsM  ...        0   310
#
# [5 rows x 7 columns]
